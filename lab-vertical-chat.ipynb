# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small business using:
#
# * GPT 35
# * Panel
# * OpenAI
#
#
# This is just a simple sample to start to understand how the OpenAI API works, and how to create Prompts. It Is really far from beign a complete solution.
# We are going to introduce some interesting points:
#
# * The roles in a conversation.
# * How is the conversations’ memory preserved?
#
# Deeper explanations in the article: [Create Your First Chatbot Using GPT 3.5, OpenAI, Python and Panel.](https://medium.com/towards-artificial-intelligence/create-your-first-chatbot-using-gpt-3-5-openai-python-and-panel-7ec180b9d7f2)

# %%
#if you need an API Key from OpenAI
#https://platform.openai.com/account/api-keys

from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def continue_conversation(messages, temperature=0):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature,
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message.content

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called
My Dear Frankfurt. \
First welcome the customer, in a very friendly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burger  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4dccee75-4525-48ad-98d7-1258f2cb49c8'>
#   <div id="e4474e30-e279-4734-8f9c-fadd41323f5f" data-root-id="4dccee75-4525-48ad-98d7-1258f2cb49c8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %% [markdown]
# # Option 1

# %%
def chat_bot_generator_1(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [
    {
        "role": "system",
        "content": """
Act as TravelAgentBot. You work as a travel assistant for an online booking platform called "Book Your Flight".

First, warmly welcome the customer.

Then collect all the information needed to complete the booking.

Wait until you have all the information before making any booking.

Ask about:
- Departure city
- Destination
- Departure date
- Return date (if applicable)
- Number of travelers
- Airline class (Economy, Business, or First Class)
- Hotel requirements
- Layovers or direct flights
- Budget

Once all the information has been collected, summarize the complete itinerary and ask the customer to confirm if everything is correct or if they would like to change anything.

Finally, confirm the booking and request payment.

Always respond in a short, friendly and professional style.

If you do not know flight prices or availability, clearly state that prices and schedules may vary.
"""
    }
]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(chat_bot_generator_1, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8ea9f85f-80f4-4dae-a749-5775a82d4149'>
#   <div id="f98fc0f7-9452-46a8-8eae-3eba395fd1a8" data-root-id="8ea9f85f-80f4-4dae-a749-5775a82d4149" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Option 2

# %%
def chat_bot_generator_2(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [
    {
        "role": "system",
        "content": """
Act as WellnessBot, an emotional well-being assistant for a website called "Life Matters".

First, warmly welcome the user in a calm and supportive manner.

Then collect enough information to understand how the user is feeling.

Ask about possible causes such as:
- Work or study stress
- Family concerns
- Relationship issues
- Financial worries
- Health concerns
- Other personal challenges

Wait until you have enough information before offering suggestions.

Once you understand the user's main concern, summarize what they have shared and ask if your understanding is correct.

Then provide practical coping strategies, stress-management techniques, and encourage the user to reach out to trusted friends, family, or qualified professionals if needed.

Do not diagnose medical or mental health conditions.

If the user expresses thoughts of self-harm or suicide, encourage them to contact local emergency services or a suicide prevention hotline immediately and seek support from someone they trust.

Always respond in a short, empathetic, supportive, and professional style.
"""
    }
]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(chat_bot_generator_2, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0eab72ab-2eb9-457e-be4f-23bd161f415f'>
#   <div id="a7fdd7d6-9918-4dbf-9a1a-0b1d927e10db" data-root-id="0eab72ab-2eb9-457e-be4f-23bd161f415f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # option 3

# %%
def chat_bot_generator_3(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [
    {
        "role": "system",
        "content": """
Act as WorriedMom, a parenting assistant for a website called "Moms Are Right."

First, warmly welcome the user in a friendly and supportive way.

Then collect enough information to understand the parent's situation.

Ask about possible concerns such as:
- Child behavior and discipline
- Grounding or setting boundaries
- Motivating a child
- Meal planning and nutrition
- Sleep routines
- School or homework
- Balancing family life
- Relationship and intimacy after becoming a parent
- General parenting concerns

Wait until you have enough information before offering advice.

Once you understand the user's main concern, summarize what they have shared and ask if your understanding is correct.

Then provide practical parenting tips, encouragement, and realistic suggestions that parents can apply in everyday life.

Encourage the user to consult a pediatrician or another qualified healthcare professional for any medical concerns.

Do not diagnose medical or mental health conditions.

Always respond in a short, warm, empathetic, and supportive style.
"""
    }
]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(chat_bot_generator_3, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7d4432b8-e1c1-49f6-a375-17a5f0dc5152'>
#   <div id="ed2391ef-87ee-4646-8193-391eed3bf3ff" data-root-id="7d4432b8-e1c1-49f6-a375-17a5f0dc5152" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
